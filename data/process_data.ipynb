# %%
import pandas as pd
# Out:
# /home/franklin/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.1' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
output_df = pd.read_csv("ghg-emissions-by-sector.csv")

# %%
input_df = pd.read_csv("annual-co2-emissions.csv")

# %%
input_df.head()
# Out:
#         Entity Code  Year  Annual CO₂ emissions
# 0  Afghanistan  AFG  1949               14656.0
# 1  Afghanistan  AFG  1950               84272.0
# 2  Afghanistan  AFG  1951               91600.0
# 3  Afghanistan  AFG  1952               91600.0
# 4  Afghanistan  AFG  1953              106256.0

# %%
output_df.head()
# Out:
#         Entity Code  Year  Greenhouse gas emissions from agriculture  \
# 0  Afghanistan  AFG  1990                                  8069999.5
# 1  Afghanistan  AFG  1991                                  8390000.0
# 2  Afghanistan  AFG  1992                                  8400000.0
# 3  Afghanistan  AFG  1993                                  8480000.0
# 4  Afghanistan  AFG  1994                                  8520000.0
#
#    Greenhouse gas emissions from land use change and forestry  \
# 0                                         -2390000.0
# 1                                         -2390000.0
# 2                                         -2390000.0
# 3                                         -2390000.0
# 4                                         -2390000.0
#
#    Greenhouse gas emissions from waste  \
# 0                            1230000.0
# 1                            1320000.0
# 2                            1400000.0
# 3                            1490000.0
# ...

# %%
import pandas as pd
import requests

# Fetch the data.
df = pd.read_csv("https://ourworldindata.org/grapher/ghg-emissions-by-sector.csv?v=1&csvType=full&useColumnShortNames=false", storage_options = {'User-Agent': 'Our World In Data data fetch/1.0'})

# Fetch the metadata
metadata = requests.get("https://ourworldindata.org/grapher/ghg-emissions-by-sector.metadata.json?v=1&csvType=full&useColumnShortNames=true").json()

# %%
output_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6355 entries, 0 to 6354
# Data columns (total 14 columns):
#  #   Column                                                         Non-Null Count  Dtype
# ---  ------                                                         --------------  -----
#  0   Entity                                                         6355 non-null   object
#  1   Code                                                           6014 non-null   object
#  2   Year                                                           6355 non-null   int64
#  3   Greenhouse gas emissions from agriculture                      6352 non-null   float64
#  4   Greenhouse gas emissions from land use change and forestry     6352 non-null   float64
#  5   Greenhouse gas emissions from waste                            6293 non-null   float64
#  6   Greenhouse gas emissions from buildings                        6228 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['Entity', 'Code', 'Year', 'Agriculture', 'Land-use change and forestry',
#        'Waste', 'Buildings', 'Industry', 'Manufacturing and construction',
#        'Transport', 'Electricity and heat', 'Fugitive emissions',
#        'Other fuel combustion', 'Aviation and shipping'],
#       dtype='object')

# %%
output_df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6969 entries, 0 to 6968
# Data columns (total 14 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Entity                          6969 non-null   object
#  1   Code                            6969 non-null   object
#  2   Year                            6969 non-null   int64
#  3   Agriculture                     6967 non-null   float64
#  4   Land-use change and forestry    6967 non-null   float64
#  5   Waste                           6868 non-null   float64
#  6   Buildings                       6718 non-null   float64
#  7   Industry                        6968 non-null   float64
#  8   Manufacturing and construction  6441 non-null   float64
#  9   Transport                       6884 non-null   float64
#  10  Electricity and heat            6852 non-null   float64
#  11  Fugitive emissions              6936 non-null   float64
# ...

# %%
df.to_csv("ghg-emissions-by-sector.csv", index=False)

# %%
df['Year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023])
